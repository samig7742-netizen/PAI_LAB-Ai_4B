# %%
Name = "sami"
Age = "20"
print(f"my name is {Name}")
print (f"my age is {Age}")
# Out:
# my name is sami
# my age is 20

# %%
Name = "sami"
Age = "20"

var_1 = Name
var_2 = Age

print(f"My name is {var_1}, Age {var_2}")
# Out:
# My name is sami, Age 20

# %%
Name = "sami"
Age = "20"

var_1 = Name
var_2 = Age
print (f"My name is {var_1},Age{var_2}")
# Out:
# My name is sami,Age20
